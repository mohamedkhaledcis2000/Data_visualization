# %%
import pandas as pd
import numpy as np

# %%
div = pd.read_csv('div.csv')
div.head(10)
div['classificated']=np.where(div[''])
# Out:
#                     ID                    Station Name  Total Docks  \
# 0                  186            Ogden Ave & Race Ave           15
# 1                  184              State St & 35th St           19
# 2                  176               Clark St & Elm St           39
# 3                  648          Carpenter St & 63rd St            7
# 4                  658        Leavitt St & Division St           15
# 5                   22              May St & Taylor St           15
# 6  1563698701206292480         Lamon Ave & Belmont Ave            9
# 7                  643                      Smith Park           15
# 8                  640         Bernard St & Elston Ave           11
# 9                  217  Elizabeth (May) St & Fulton St           15
#
#    Docks in Service      Status   Latitude  Longitude  \
# 0                15  In Service  41.891795 -87.658751
# 1                19  In Service  41.831036 -87.626798
# ...
